# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('flat.csv', sep='\t', index_col='n')

# %%
print(f'size of dataframe {df.shape}')
df.head()
# Out:
# size of dataframe (2040, 10)
#    price  totsp  livesp  kitsp  dist  metrdist  walk  brick  floor  code
# n
# 1     81     58      40    6.0  12.5         7     1      1      1     3
# 2     75     44      28    6.0  13.5         7     1      0      1     6
# 3    128     70      42    6.0  14.5         3     1      1      1     3
# 4     95     61      37    6.0  13.5         7     1      0      1     1
# 5    330    104      60   11.0  10.5         7     0      1      1     3

# %%
df.info() # get info about types of variables in dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2040 entries, 1 to 2040
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   price     2040 non-null   int64
#  1   totsp     2040 non-null   int64
#  2   livesp    2040 non-null   int64
#  3   kitsp     2040 non-null   float64
#  4   dist      2040 non-null   float64
#  5   metrdist  2040 non-null   int64
#  6   walk      2040 non-null   int64
#  7   brick     2040 non-null   int64
#  8   floor     2040 non-null   int64
#  9   code      2040 non-null   int64
# dtypes: float64(2), int64(8)
# memory usage: 175.3 KB

# %%
df.describe()
# Out:
#              price        totsp       livesp        kitsp         dist  \
# count  2040.000000  2040.000000  2040.000000  2040.000000  2040.000000
# mean    127.496569    73.084314    46.337255     8.898529    11.015686
# std      51.878220    15.123450     7.894348     2.787073     3.375539
# min      50.000000    44.000000    28.000000     5.000000     3.000000
# 25%      95.000000    62.000000    42.000000     7.000000     9.000000
# 50%     115.000000    73.500000    45.000000     9.000000    12.000000
# 75%     142.000000    79.000000    50.000000    10.000000    13.500000
# max     730.000000   192.000000   102.000000    25.000000    17.000000
#
#           metrdist         walk        brick        floor         code
# count  2040.000000  2040.000000  2040.000000  2040.000000  2040.000000
# mean      8.117157     0.685784     0.323039     0.790686     4.322059
# std       3.815574     0.464317     0.467752     0.406918     2.183289
# ...

# %%
df.isnull().sum() # counts quantity of null values
# Out:
# price       0
# totsp       0
# livesp      0
# kitsp       0
# dist        0
# metrdist    0
# walk        0
# brick       0
# floor       0
# code        0
# dtype: int64

# %%
""" 
get info about price distribution. If we see a bunch of outliers we
need to take this into account. If we have outliers we need to do 

"""
df.price.hist(bins=30) 
# sns.heatmap(df.corr(),)
# Out:
# <AxesSubplot:>

# %%
df.price.plot.box()
# Out:
# <AxesSubplot:>

# %%
df.price = np.log(df.price)

# %%
df.price.plot.hist(bins=30)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.price.plot.box()
# Out:
# <AxesSubplot:>

# %%
plt.plot(np.log(np.array(range(1,1000))));

# %%
df.drop('price', axis=1).hist(figsize=(20, 12));

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df)

# %%
df.head()
# Out:
#       price  totsp  livesp  kitsp  dist  metrdist  walk  brick  floor  code
# n
# 1  4.394449     58      40    6.0  12.5         7     1      1      1     3
# 2  4.317488     44      28    6.0  13.5         7     1      0      1     6
# 3  4.852030     70      42    6.0  14.5         3     1      1      1     3
# 4  4.553877     61      37    6.0  13.5         7     1      0      1     1
# 5  5.799093    104      60   11.0  10.5         7     0      1      1     3

# %%
# One hot encoding

# %%
ds = pd.DataFrame(['good', 'medium', 'bad'])

# %%
ds
# Out:
#         0
# 0    good
# 1  medium
# 2     bad

# %%
pd.get_dummies(ds)
# Out:
#    0_bad  0_good  0_medium
# 0      0       1         0
# 1      0       0         1
# 2      1       0         0

# %%
from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder()

# %%
# create OHE for cathegorical variable

df_category = pd.get_dummies(df['code'], drop_first=True, prefix='code')

# join our tables

df = pd.concat([df.drop('code', axis=1), df_category], axis=1)

# %%
df
# Out:
#          price  totsp  livesp  kitsp  dist  metrdist  walk  brick  floor  \
# n
# 1     4.394449     58      40    6.0  12.5         7     1      1      1
# 2     4.317488     44      28    6.0  13.5         7     1      0      1
# 3     4.852030     70      42    6.0  14.5         3     1      1      1
# 4     4.553877     61      37    6.0  13.5         7     1      0      1
# 5     5.799093    104      60   11.0  10.5         7     0      1      1
# ...        ...    ...     ...    ...   ...       ...   ...    ...    ...
# 2036  4.700480     77      45   10.0  12.0         5     0      0      1
# 2037  4.553877     60      43    6.0   9.0         5     0      0      1
# 2038  4.553877     60      46    5.0  10.5         5     1      0      1
# 2039  4.859812     76      48   10.0  12.5         5     0      0      1
# 2040  4.634729     64      45    7.0  15.5         5     1      0      1
#
#       code_2  code_3  code_4  code_5  code_6  code_7  code_8
# n
# ...
